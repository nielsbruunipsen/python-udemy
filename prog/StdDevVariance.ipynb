# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

for i in range(10):
    print(incomes[i])
# Out:
# 222.153072968
# 198.042525596
# 23.0294412198
# 88.8617257049
# 96.4019637608
# 59.1942905235
# 91.9246604803
# 85.6034372866
# 133.707299826
# 58.5174301707

# %%
incomes.std()
# Out:
# 50.225526766642119

# %%
incomes.var()
# Out:
# 2479.4679169054948

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
from scipy.stats import norm

data = np.random.normal(10,100,10000)
plt.hist(data,50,range=(-400,400))
x = np.arange(-400,400,1)
plt.plot(x,norm.pdf(x,10,100)*(10000*16))
plt.show()
